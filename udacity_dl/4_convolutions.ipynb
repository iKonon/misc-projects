# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.916021
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.408493
# Minibatch accuracy: 56.2%
# Validation accuracy: 40.8%
# Minibatch loss at step 100: 0.765961
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.9%
# Minibatch loss at step 150: 0.706176
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.2%
# Minibatch loss at step 200: 0.551793
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 250: 1.076569
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.5%
# Minibatch loss at step 300: 0.495823
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 350: 0.353270
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 400: 0.715028
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 0.349615
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 500: 0.955165
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 550: 0.949600
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 600: 0.462281
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 650: 0.794729
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 700: 0.174542
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 750: 0.372376
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 0.601005
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 850: 0.369773
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 900: 0.881725
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 950: 1.263622
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 1000: 0.323040
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Test accuracy: 89.7%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))

    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

    layer3_weights = tf.Variable(
        tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))


    # Model.
    def model(data):
        conv1 = tf.nn.relu(tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME') + layer1_biases)
        pool1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        conv2 = tf.nn.relu(tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME') + layer2_biases)
        pool2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
        fc1 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(fc1, layer4_weights) + layer4_biases


    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Max pool Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-8-54a6a74258f1>:61: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 2.692399
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.958270
# Minibatch accuracy: 37.5%
# Validation accuracy: 41.8%
# Minibatch loss at step 100: 0.994979
# Minibatch accuracy: 81.2%
# Validation accuracy: 67.2%
# Minibatch loss at step 150: 0.835487
# Minibatch accuracy: 81.2%
# Validation accuracy: 60.1%
# Minibatch loss at step 200: 0.786120
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.9%
# Minibatch loss at step 250: 1.168362
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 300: 0.608841
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 350: 0.327498
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 400: 0.757403
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 0.565047
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 500: 0.883706
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 550: 0.707928
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 600: 0.346891
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 650: 0.673135
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 700: 0.262294
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 750: 0.436652
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 800: 0.447755
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 0.389659
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 900: 0.729316
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 950: 1.151991
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.240240
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Max pool Test accuracy: 90.3%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 32
num_hidden = 64
num_steps = 30001

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    global_step = tf.Variable(0)  # count the number of steps taken.

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))

    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

    layer3_weights = tf.Variable(
        tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))


    # Model.
    def model(data, keep_prob):
        conv1 = tf.nn.relu(tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME') + layer1_biases)
        pool1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        conv2 = tf.nn.relu(tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME') + layer2_biases)
        pool2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
        fc1 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        fc1_drop = tf.nn.dropout(fc1, keep_prob)

        y_conv = tf.nn.softmax(tf.matmul(fc1_drop, layer4_weights) + layer4_biases)

        return y_conv


    # Training computation.
    y_conv = model(tf_train_dataset, 0.5)
    y_ = tf_train_labels
    cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(y_conv), reduction_indices=[1]))

    loss = cross_entropy + 0.001 * (
        tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases) + tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(
            layer4_biases))

    # Optimizer.
    learning_rate = tf.train.exponential_decay(1e-1, global_step, num_steps, 0.7, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = y_conv
    valid_prediction = model(tf_valid_dataset, 1.0)
    test_prediction = model(tf_test_dataset, 1.0)

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 300 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Lenet 5 Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-9-fe88fcaf42c8>:70: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 5.740284
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 300: 1.444100
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 600: 0.906798
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 900: 1.011403
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 1200: 1.214209
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 1500: 1.231745
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 1800: 0.669655
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 2100: 0.821394
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 2400: 0.689628
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 2700: 0.739251
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 3000: 0.970564
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 3300: 0.579732
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 3600: 1.149266
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 3900: 0.846250
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 4200: 1.169660
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 4500: 0.703324
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 4800: 0.574325
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 5100: 0.873016
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 5400: 0.956389
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 5700: 0.699962
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 6000: 1.019246
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 6300: 0.827590
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 6600: 0.550547
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 6900: 1.049120
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 7200: 0.604308
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 7500: 0.506543
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 7800: 0.655380
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 8100: 1.038529
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 8400: 0.524689
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 8700: 0.704288
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 9000: 0.515245
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 9300: 0.485635
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 9600: 1.151436
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 9900: 1.053887
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 10200: 0.974606
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 10500: 0.402112
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 10800: 0.478465
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 11100: 0.772296
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 11400: 0.949162
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 11700: 0.683354
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 12000: 0.851693
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 12300: 1.072104
# Minibatch accuracy: 56.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 12600: 0.731911
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 12900: 1.115068
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 13200: 0.398632
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 13500: 0.827871
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 13800: 0.857318
# Minibatch accuracy: 62.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 14100: 0.796461
# Minibatch accuracy: 68.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 14400: 0.397869
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 14700: 0.599104
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 15000: 0.709793
# Minibatch accuracy: 68.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 15300: 1.411140
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 15600: 0.476673
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 15900: 0.657903
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 16200: 0.488901
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 16500: 0.610338
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 16800: 0.096153
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 17100: 0.571996
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 17400: 0.287982
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 17700: 0.464531
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 18000: 1.414757
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 18300: 0.727916
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 18600: 0.498223
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 18900: 0.453352
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 19200: 0.557976
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 19500: 0.119769
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 19800: 0.328151
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 20100: 0.093178
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 20400: 0.144534
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 20700: 0.716046
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 21000: 0.324598
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 21300: 1.208041
# Minibatch accuracy: 68.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 21600: 0.413503
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 21900: 0.941807
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 22200: 0.282972
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 22500: 0.526527
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 22800: 0.733849
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 23100: 0.380426
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 23400: 0.688017
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 23700: 0.472073
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 24000: 0.578790
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 24300: 0.188164
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 24600: 0.426276
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 24900: 0.483039
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 25200: 0.772626
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 25500: 0.622672
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 25800: 0.713587
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 26100: 1.301773
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 26400: 0.849465
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 26700: 0.548489
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 27000: 0.146134
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 27300: 0.420234
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 27600: 0.341846
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 27900: 0.533683
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 28200: 0.545062
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 28500: 0.675835
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 28800: 0.271962
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 29100: 0.645111
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 29400: 0.738476
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 29700: 0.437031
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 30000: 0.418735
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.7%
# Lenet 5 Test accuracy: 95.4%
