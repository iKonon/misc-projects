# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'of', 'originated', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.194532
# Nearest to had: collectors, wes, dutt, transubstantiation, archers, carolus, operatic, bonds,
# Nearest to united: lilac, mcdonalds, disclose, ornamental, marion, leadership, protagonist, decarlo,
# Nearest to in: richest, housekeeper, angleton, upholds, pf, neurath, pip, dipping,
# Nearest to no: nor, antics, vre, charleston, envelope, novorossiysk, concentric, adventure,
# Nearest to from: sata, jarring, constructive, symmetrical, strongest, harmonicas, subscribers, motley,
# Nearest to can: implements, alif, casino, rhymes, motherboard, lycus, interlude, dor,
# Nearest to into: uzi, grape, reasoned, broadcasting, geological, happiness, soma, unbelievers,
# Nearest to s: summarizing, hashing, allgemeine, nadu, adjusts, condon, julia, vineyards,
# Nearest to seven: achaea, bleaching, ramesh, nihilo, clubhouse, lubbock, biases, nicknamed,
# Nearest to eight: wipo, continental, transduction, digit, palm, intentionality, tribunal, superheroic,
# Nearest to to: insensible, cohabitation, perjury, eduskunta, censuses, frontage, demonolatry, meredith,
# Nearest to see: minimum, mycelium, headstock, speaking, abstracts, shaft, arawak, gylfaginning,
# Nearest to as: poetics, goodwin, slingshot, eutelsat, zeroes, tha, penny, murky,
# Nearest to is: cubist, rejoined, kaiju, blah, flight, vegetal, renal, frau,
# Nearest to up: salmonella, matriculation, cassettes, curiae, deaf, questionable, instructions, yeti,
# Nearest to after: defence, steeper, hitler, ainsworth, melancholic, foundationalism, basil, hemorrhage,
# Average loss at step 2000: 4.369015
# Average loss at step 4000: 3.863774
# Average loss at step 6000: 3.790964
# Average loss at step 8000: 3.687117
# Average loss at step 10000: 3.622672
# Nearest to had: has, have, was, archers, were, garth, cob, suu,
# Nearest to united: world, knock, masai, yukon, wainwright, ornamental, slates, coding,
# Nearest to in: of, from, on, for, bfbs, with, at, overbearing,
# Nearest to no: antics, it, concentric, pickups, a, nor, vre, foretold,
# Nearest to from: into, in, on, caitlin, with, by, killing, srinagar,
# Nearest to can: casino, may, could, would, airbus, rhymes, might, interlude,
# Nearest to into: from, broadcasting, constituency, swapped, citt, hogan, bargaining, refutation,
# Nearest to s: his, radioactive, accumulator, alameda, piccolo, and, truss, beos,
# Nearest to seven: eight, six, three, nine, five, four, zero, two,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to to: wavering, not, numidia, kamov, transcending, would, could, hammer,
# Nearest to see: intrusive, mycelium, greenery, irritable, main, abstracts, modulation, shaft,
# Nearest to as: involve, gs, hemispheres, poetics, fibre, hong, been, decision,
# Nearest to is: was, are, has, were, be, insane, by, scientifically,
# Nearest to up: deaf, affectation, connotation, questionable, aluminum, salmonella, neale, matriculation,
# Nearest to after: configure, trains, culminating, defence, pretended, over, conjugated, practitioner,
# Average loss at step 12000: 3.602679
# Average loss at step 14000: 3.567310
# Average loss at step 16000: 3.414384
# Average loss at step 18000: 3.455316
# Average loss at step 20000: 3.542417
# Nearest to had: has, have, was, were, archers, having, been, intermittent,
# Nearest to united: world, knock, wainwright, masai, cahiers, yukon, colorado, middle,
# Nearest to in: at, on, within, with, for, from, under, statically,
# Nearest to no: antics, haart, vre, pickups, concentric, it, a, nor,
# Nearest to from: into, between, in, villain, killing, caitlin, hardliners, by,
# Nearest to can: may, could, would, will, might, should, must, cannot,
# Nearest to into: from, constituency, broadcasting, citt, bogus, by, philosophicus, swapped,
# Nearest to s: piccolo, alameda, truss, homers, xc, radioactive, daley, tro,
# Nearest to seven: six, eight, nine, four, five, zero, three, two,
# Nearest to eight: six, nine, seven, four, five, zero, three, two,
# Nearest to to: would, will, may, could, numidia, wavering, can, perjury,
# Nearest to see: greenery, intrusive, abstracts, expands, modulation, hogeschool, shaft, adapter,
# Nearest to as: involve, without, almohades, cappella, reset, fists, hypomanic, cinco,
# Nearest to is: was, has, are, were, inhabit, malpractice, although, hayt,
# Nearest to up: him, supply, aluminum, affectation, scoring, them, acupuncture, deaf,
# Nearest to after: before, when, sermon, over, during, colette, mistakenly, penned,
# Average loss at step 22000: 3.502598
# Average loss at step 24000: 3.489871
# Average loss at step 26000: 3.479362
# Average loss at step 28000: 3.476852
# Average loss at step 30000: 3.500363
# Nearest to had: have, has, was, were, having, carpenters, cob, is,
# Nearest to united: world, knock, wainwright, masai, eastern, minutemen, cahiers, yukon,
# Nearest to in: on, during, at, of, with, within, under, from,
# Nearest to no: haart, antics, any, a, vre, only, rom, phys,
# Nearest to from: into, between, through, under, in, on, of, over,
# Nearest to can: may, could, would, will, must, cannot, should, might,
# Nearest to into: from, through, under, over, bogus, on, within, constituency,
# Nearest to s: his, alameda, isbn, piccolo, radioactive, sur, raymond, advise,
# Nearest to seven: nine, eight, four, six, five, three, zero, two,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to to: would, wavering, can, could, will, numidia, for, fiske,
# Nearest to see: greenery, cipher, phoenician, list, intrusive, hogeschool, throttle, pastry,
# Nearest to as: programmatic, posit, involve, by, or, pashtun, ges, photons,
# Nearest to is: was, has, are, while, be, heft, became, although,
# Nearest to up: him, them, supply, out, down, way, aluminum, divorces,
# Nearest to after: before, when, during, colette, following, in, from, dostoyevsky,
# Average loss at step 32000: 3.500898
# Average loss at step 34000: 3.496729
# Average loss at step 36000: 3.457646
# Average loss at step 38000: 3.304293
# Average loss at step 40000: 3.424235
# Nearest to had: has, have, was, were, bracketed, having, commented, wrote,
# Nearest to united: minutemen, eastern, wainwright, knock, masai, cahiers, yukon, gleaming,
# Nearest to in: within, at, of, and, on, during, for, from,
# Nearest to no: any, antics, haart, vre, ansi, than, strictly, airbases,
# Nearest to from: into, through, over, motley, between, in, after, under,
# Nearest to can: may, could, will, would, might, must, should, cannot,
# Nearest to into: from, through, over, bogus, during, philosophicus, pleasure, constituency,
# Nearest to s: his, fitted, rotunda, tramway, would, radios, nutshell, whose,
# Nearest to seven: five, six, eight, nine, four, zero, three, two,
# Nearest to eight: nine, seven, six, four, five, zero, three, one,
# Nearest to to: will, numidia, must, may, would, envious, wavering, can,
# Nearest to see: list, intrusive, include, but, pinus, mammoths, phoenician, antioxidant,
# Nearest to as: by, cinco, when, be, substrates, involve, almohades, programmatic,
# Nearest to is: was, are, has, if, be, while, being, attractiveness,
# Nearest to up: them, him, out, supply, down, divorces, way, dah,
# Nearest to after: before, when, during, while, colette, from, following, regulus,
# Average loss at step 42000: 3.434364
# Average loss at step 44000: 3.452662
# Average loss at step 46000: 3.453717
# Average loss at step 48000: 3.353207
# Average loss at step 50000: 3.384987
# Nearest to had: has, have, was, were, having, been, commented, bracketed,
# Nearest to united: minutemen, wainwright, eastern, phage, gleaming, eine, masai, middle,
# Nearest to in: within, on, during, from, under, since, of, throughout,
# Nearest to no: any, a, antics, haart, airbases, pickups, ansi, chanukah,
# Nearest to from: into, through, in, under, between, on, at, after,
# Nearest to can: could, may, would, will, must, might, should, cannot,
# Nearest to into: through, from, over, constituency, around, bogus, under, during,
# Nearest to s: alameda, whose, and, tramway, absolutely, odore, engler, sparkling,
# Nearest to seven: six, nine, eight, four, five, three, zero, two,
# Nearest to eight: six, seven, nine, four, five, zero, three, one,
# Nearest to to: numidia, could, may, will, would, can, cannot, enunciated,
# Nearest to see: include, macbeth, hogeschool, external, cipher, references, seti, list,
# Nearest to as: became, when, involve, better, almohades, wikiproject, very, plebs,
# Nearest to is: was, has, are, became, does, be, although, transpired,
# Nearest to up: out, them, him, down, supply, off, hardest, goshen,
# Nearest to after: before, when, during, while, following, under, colette, if,
# Average loss at step 52000: 3.439496
# Average loss at step 54000: 3.428868
# Average loss at step 56000: 3.438729
# Average loss at step 58000: 3.398231
# Average loss at step 60000: 3.391300
# Nearest to had: has, have, was, were, having, been, commented, shipbuilding,
# Nearest to united: minutemen, wainwright, gleaming, phage, eine, yukon, knock, masai,
# Nearest to in: within, during, from, since, of, throughout, into, until,
# Nearest to no: any, chanukah, antics, pickups, haart, airbases, ansi, icp,
# Nearest to from: into, through, in, under, motley, bean, between, villain,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to into: through, from, over, within, under, in, around, constituency,
# Nearest to s: isbn, whose, typing, sparkling, tramway, horseshoes, interrogations, reactionary,
# Nearest to seven: eight, six, nine, four, five, zero, three, two,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to to: numidia, leah, therein, not, will, annum, cripps, would,
# Nearest to see: external, include, hogeschool, and, list, but, can, references,
# Nearest to as: involve, almohades, when, became, exerts, by, pashtun, blooming,
# Nearest to is: was, are, has, seems, although, be, became, malpractice,
# Nearest to up: out, them, down, him, supply, off, back, detachment,
# Nearest to after: before, when, during, while, without, following, although, under,
# Average loss at step 62000: 3.244013
# Average loss at step 64000: 3.249206
# Average loss at step 66000: 3.400833
# Average loss at step 68000: 3.399493
# Average loss at step 70000: 3.361254
# Nearest to had: has, have, was, were, having, commented, bracketed, been,
# Nearest to united: minutemen, wainwright, yukon, phage, dari, knock, gleaming, netherlands,
# Nearest to in: within, on, during, until, throughout, westeros, spinner, since,
# Nearest to no: any, chanukah, ansi, quotients, little, jakarta, invalid, haart,
# Nearest to from: through, into, in, quo, before, between, over, jh,
# Nearest to can: could, may, would, will, might, must, should, cannot,
# Nearest to into: through, from, over, within, reasoned, under, constituency, gras,
# Nearest to s: odore, penthouse, sur, tit, gynt, tro, horseshoes, rotunda,
# Nearest to seven: six, eight, nine, five, four, three, zero, one,
# Nearest to eight: nine, six, seven, four, five, zero, three, one,
# Nearest to to: numidia, will, can, must, for, fiske, narrating, would,
# Nearest to see: include, macbeth, hogeschool, external, list, references, seti, phoenician,
# Nearest to as: involve, before, landline, like, when, becomes, frisbee, almohades,
# Nearest to is: was, has, are, be, maintains, although, malpractice, makes,
# Nearest to up: out, them, down, him, supply, off, back, detachment,
# Nearest to after: before, during, when, while, without, following, despite, fief,
# Average loss at step 72000: 3.373039
# Average loss at step 74000: 3.346406
# Average loss at step 76000: 3.320201
# Average loss at step 78000: 3.351247
# Average loss at step 80000: 3.377716
# Nearest to had: have, has, were, was, having, bracketed, commented, been,
# Nearest to united: minutemen, knock, negation, wainwright, eine, gleaming, netherlands, colorado,
# Nearest to in: within, during, on, throughout, at, until, under, since,
# Nearest to no: any, little, glow, mistrust, jakarta, pickups, quotients, technocrats,
# Nearest to from: into, through, in, across, while, madras, embedding, during,
# Nearest to can: could, may, would, will, must, might, cannot, should,
# Nearest to into: through, from, within, over, under, constituency, pratt, gras,
# Nearest to s: gynt, alameda, daley, isbn, whose, sari, discreet, machete,
# Nearest to seven: six, five, eight, four, nine, three, zero, one,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to to: numidia, will, cannot, must, echelon, would, lleida, cuc,
# Nearest to see: include, macbeth, seti, references, phoenician, greenery, refer, external,
# Nearest to as: involve, gs, cinco, lamp, venues, becomes, aiming, after,
# Nearest to is: was, has, are, seems, remains, requires, although, maintains,
# Nearest to up: out, down, them, him, off, supply, back, goshen,
# Nearest to after: before, during, when, without, while, despite, following, if,
# Average loss at step 82000: 3.405301
# Average loss at step 84000: 3.412217
# Average loss at step 86000: 3.391490
# Average loss at step 88000: 3.352215
# Average loss at step 90000: 3.364677
# Nearest to had: has, have, was, having, were, bracketed, never, did,
# Nearest to united: minutemen, wainwright, netherlands, colorado, navy, gleaming, knock, yukon,
# Nearest to in: during, within, with, throughout, at, under, of, on,
# Nearest to no: any, little, only, airbases, installer, chanukah, evidence, strictly,
# Nearest to from: into, through, across, towards, dyed, under, during, repayment,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to into: through, from, under, over, within, supplanting, toot, down,
# Nearest to s: whose, isbn, gynt, tramway, his, pinning, partials, engler,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Nearest to eight: seven, nine, six, five, four, zero, three, two,
# Nearest to to: numidia, will, towards, would, traverse, transcending, eduskunta, leah,
# Nearest to see: references, list, links, external, include, refer, phoenician, il,
# Nearest to as: avionics, cinco, frisbee, particularly, swung, gs, substrates, ranch,
# Nearest to is: was, has, are, makes, although, requires, seems, became,
# Nearest to up: out, down, them, off, him, back, supply, together,
# Nearest to after: before, when, during, without, while, until, despite, if,
# Average loss at step 92000: 3.396449
# Average loss at step 94000: 3.253581
# Average loss at step 96000: 3.356839
# Average loss at step 98000: 3.243633
# Average loss at step 100000: 3.357646
# Nearest to had: has, have, was, having, is, did, bracketed, were,
# Nearest to united: minutemen, netherlands, constitution, democratic, navy, gleaming, wainwright, colorado,
# Nearest to in: within, during, throughout, on, until, from, at, near,
# Nearest to no: any, little, haart, technocrats, seljuk, strictly, vpi, robo,
# Nearest to from: in, into, through, gracious, during, disrupts, olsen, theoretician,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to into: through, within, from, over, under, supplanting, across, in,
# Nearest to s: his, whose, gynt, isbn, woke, madam, schottenheimer, sparkling,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Nearest to eight: seven, nine, six, four, five, zero, three, two,
# Nearest to to: numidia, will, could, can, would, kamov, should, must,
# Nearest to see: references, external, links, list, refer, include, includes, il,
# Nearest to as: substrates, involve, protozoa, becomes, plebs, wikiproject, landline, posit,
# Nearest to is: was, has, seems, are, becomes, became, had, be,
# Nearest to up: out, down, them, off, him, supply, back, straight,
# Nearest to after: before, during, when, despite, while, without, until, although,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
bag_window = 2  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases,\
                                   inputs=tf.reduce_sum(embeds, 1),\
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()

num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])


def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']
# WARNING:tensorflow:From <ipython-input-15-620ca1a1359f>:80: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.976877
# Nearest to are: doing, odo, licensee, salting, mcconnell, clothes, dynamite, bayesian,
# Nearest to all: jakobson, myung, autographed, hurtful, fowler, childress, lightning, fright,
# Nearest to who: hurrians, reconciliation, lake, courts, augment, dared, absurdum, install,
# Nearest to their: krzy, controllers, patmos, complaints, camping, rules, interpret, tolson,
# Nearest to his: amal, kilda, extremophiles, hapless, secundus, rockford, naturalistic, villein,
# Nearest to with: ostwald, octavio, sld, anthroposophy, probus, obfuscation, clu, irish,
# Nearest to from: occam, saw, pairs, graeco, exon, winding, slight, genji,
# Nearest to eight: sanctions, entendre, feudal, page, shir, tuamotu, circularly, demoted,
# Nearest to these: gale, sinking, transitivity, selene, pows, erupting, ddo, miscarriages,
# Nearest to that: eredivisie, caracalla, coincidence, spee, occultation, rugged, tgs, dumfries,
# Nearest to at: monmouth, osr, averaged, ichi, khagan, pennant, theoretician, judge,
# Nearest to i: epilepsy, iuds, webber, civilisations, interdisciplinary, incrementally, intent, eurasian,
# Nearest to or: fortresses, rush, fgc, why, lutheranism, removing, assisi, sicily,
# Nearest to four: reggie, baseman, expropriation, nonterminal, rowboat, mongolia, governed, thaddeus,
# Nearest to a: debugging, karenina, farnsworth, catastrophic, yearbook, martyr, packet, disrupts,
# Nearest to there: diminish, przewodnicz, inwardly, melvyn, youth, portable, pile, gaon,
# Average loss at step 2000: 4.641852
# Average loss at step 4000: 3.947207
# Average loss at step 6000: 3.729303
# Average loss at step 8000: 3.536682
# Average loss at step 10000: 3.478021
# Nearest to are: were, is, was, do, banjos, have, presentations, has,
# Nearest to all: many, these, some, several, nodules, donoghue, others, haaretz,
# Nearest to who: he, spinet, which, gorgeous, they, unwelcome, maneuver, that,
# Nearest to their: its, his, her, our, the, idf, pest, barbary,
# Nearest to his: their, her, its, our, cass, expressiveness, ebook, ejection,
# Nearest to with: ppg, confirms, hen, dirac, fibrous, geoffroy, andersonville, cursed,
# Nearest to from: through, into, tuned, lucasarts, tuscany, argumentative, nn, motorbikes,
# Nearest to eight: nine, six, five, seven, three, four, zero, spell,
# Nearest to these: there, all, driver, other, some, different, vilhelm, they,
# Nearest to that: which, montju, freedoms, sinbad, occupiers, cingular, sexes, diabetic,
# Nearest to at: luddite, warden, booting, encapsulated, ichi, selene, ciprofloxacin, partnered,
# Nearest to i: we, ii, playmate, willi, undertakings, iii, erasmus, avidly,
# Nearest to or: than, and, reassured, invoked, recordings, contemplates, approaches, atolls,
# Nearest to four: five, three, six, eight, seven, zero, nine, two,
# Nearest to a: any, the, this, an, another, menstruation, reisman, no,
# Nearest to there: it, these, latinus, they, longer, reliance, downplay, baekje,
# Average loss at step 12000: 3.486508
# Average loss at step 14000: 3.442766
# Average loss at step 16000: 3.447281
# Average loss at step 18000: 3.406029
# Average loss at step 20000: 3.211335
# Nearest to are: were, is, include, was, have, monadic, irving, banjos,
# Nearest to all: several, many, both, donoghue, these, various, polyphonic, some,
# Nearest to who: spinet, which, he, faso, shulkhan, and, sit, she,
# Nearest to their: its, his, her, our, the, miskelley, sommerfeld, barbary,
# Nearest to his: their, her, its, our, the, s, principe, eminence,
# Nearest to with: between, using, dirac, while, aemilius, intractable, christianization, sld,
# Nearest to from: through, into, against, in, culminating, during, jug, molybdenum,
# Nearest to eight: nine, seven, four, three, six, five, zero, lorre,
# Nearest to these: many, various, different, some, all, other, those, certain,
# Nearest to that: which, where, however, when, this, although, what, visuals,
# Nearest to at: when, during, encapsulated, wmo, warden, comprises, while, hyllus,
# Nearest to i: we, ii, you, g, proponent, mcghee, arcs, transponder,
# Nearest to or: and, distortion, than, diena, endosymbiotic, howie, incorporation, rodgers,
# Nearest to four: six, three, seven, five, eight, two, zero, draped,
# Nearest to a: the, an, another, menstruation, deuterocanonical, each, every, oceanography,
# Nearest to there: they, reliance, it, latinus, supercomputer, called, longer, finishes,
# Average loss at step 22000: 3.356970
# Average loss at step 24000: 3.294071
# Average loss at step 26000: 3.262938
# Average loss at step 28000: 3.291155
# Average loss at step 30000: 3.230746
# Nearest to are: were, is, was, include, monadic, minigun, assemblages, kills,
# Nearest to all: many, some, various, these, both, several, those, most,
# Nearest to who: that, which, young, gorgeous, spinet, while, faso, abramovich,
# Nearest to their: its, his, our, the, her, miskelley, excerpts, goodwin,
# Nearest to his: her, their, its, my, the, our, renal, barbary,
# Nearest to with: between, intractable, dualistic, christianization, bleach, geoffroy, eel, quart,
# Nearest to from: through, into, in, back, during, bethlen, near, slogan,
# Nearest to eight: nine, six, seven, five, zero, four, three, c,
# Nearest to these: different, various, all, certain, some, many, other, those,
# Nearest to that: which, who, because, when, where, montju, klerk, while,
# Nearest to at: encapsulated, warden, since, multiplies, inr, weston, near, lauded,
# Nearest to i: g, ii, we, mcghee, he, erasmus, rumored, qu,
# Nearest to or: and, reassured, jakobson, logie, lavishly, lesley, than, personage,
# Nearest to four: five, three, seven, six, eight, nine, zero, vald,
# Nearest to a: another, the, any, every, an, boucher, no, this,
# Nearest to there: they, supercomputer, it, she, longer, considered, which, couples,
# Average loss at step 32000: 3.014726
# Average loss at step 34000: 3.205231
# Average loss at step 36000: 3.194139
# Average loss at step 38000: 3.156004
# Average loss at step 40000: 3.165163
# Nearest to are: were, is, was, include, have, being, do, exist,
# Nearest to all: many, various, several, every, any, some, these, jute,
# Nearest to who: rift, which, faso, zahir, reine, whom, ahura, tum,
# Nearest to their: its, his, our, her, my, the, your, miskelley,
# Nearest to his: her, their, its, my, our, your, the, s,
# Nearest to with: between, sloan, while, against, papyri, cures, christianization, repeaters,
# Nearest to from: into, within, through, sumerians, radbruch, including, across, in,
# Nearest to eight: seven, five, six, nine, four, three, zero, khanate,
# Nearest to these: various, different, certain, those, they, there, several, all,
# Nearest to that: which, however, although, what, when, eliezer, where, because,
# Nearest to at: on, encapsulated, warden, over, wines, during, geelong, since,
# Nearest to i: ii, g, decentralisation, we, parentage, iii, oblivion, they,
# Nearest to or: and, than, non, pics, enid, egoism, demos, mep,
# Nearest to four: five, seven, six, three, eight, two, zero, nine,
# Nearest to a: another, any, the, every, each, this, boucher, falsificationism,
# Nearest to there: considered, longer, it, supercomputer, these, he, they, she,
# Average loss at step 42000: 3.212627
# Average loss at step 44000: 3.146869
# Average loss at step 46000: 3.141670
# Average loss at step 48000: 3.051521
# Average loss at step 50000: 3.068076
# Nearest to are: were, is, include, was, being, exist, have, miscellany,
# Nearest to all: many, various, several, some, every, any, numerous, polyphonic,
# Nearest to who: which, aubier, senior, he, reine, picasso, admixture, rift,
# Nearest to their: its, his, our, her, the, your, my, whose,
# Nearest to his: her, their, its, my, the, our, your, s,
# Nearest to with: between, confirms, intractable, using, geoffroy, sidespin, quart, ppg,
# Nearest to from: into, through, during, mechon, radbruch, kibbutz, tanzanian, qed,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to these: different, various, several, certain, many, other, some, numerous,
# Nearest to that: which, however, what, where, montju, although, when, extramarital,
# Nearest to at: warden, near, encapsulated, record, multiplies, mellon, deficits, during,
# Nearest to i: ii, g, iii, decentralisation, drumming, avidly, we, tabari,
# Nearest to or: and, than, radar, sales, etc, wisegirls, displacements, millisecond,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to a: another, the, any, every, falsificationism, his, boucher, despotate,
# Nearest to there: they, it, considered, she, finishes, he, latinus, essentially,
# Average loss at step 52000: 3.099951
# Average loss at step 54000: 3.093075
# Average loss at step 56000: 2.919268
# Average loss at step 58000: 3.029297
# Average loss at step 60000: 3.047464
# Nearest to are: were, is, include, was, including, exist, remain, have,
# Nearest to all: various, several, many, some, both, any, these, numerous,
# Nearest to who: he, already, which, aubier, cadets, tum, pivot, whom,
# Nearest to their: its, his, our, her, the, your, whose, my,
# Nearest to his: her, their, its, our, your, my, s, the,
# Nearest to with: between, among, geoffroy, bleach, diabetics, including, portmanteaus, motivations,
# Nearest to from: through, into, wachowski, radbruch, bronfman, subjecting, portman, qed,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to these: different, several, various, all, certain, some, multiple, many,
# Nearest to that: which, where, what, when, because, still, klerk, ethica,
# Nearest to at: near, in, warden, luddite, encapsulated, across, during, on,
# Nearest to i: ii, you, iii, funnel, iv, they, avidly, dahalo,
# Nearest to or: and, than, howie, mano, gra, while, boudin, raiding,
# Nearest to four: five, three, six, seven, eight, zero, two, nine,
# Nearest to a: another, any, the, every, this, no, an, falsificationism,
# Nearest to there: longer, it, they, lukashenko, called, required, latinus, essentially,
# Average loss at step 62000: 3.011865
# Average loss at step 64000: 2.918878
# Average loss at step 66000: 2.937286
# Average loss at step 68000: 2.953022
# Average loss at step 70000: 3.008924
# Nearest to are: were, is, was, include, monadic, have, minigun, exist,
# Nearest to all: many, several, various, numerous, some, haaretz, certain, every,
# Nearest to who: he, whose, which, snowboarding, actually, stow, she, whom,
# Nearest to their: its, his, her, our, your, the, these, my,
# Nearest to his: their, her, its, my, your, our, the, s,
# Nearest to with: between, when, motivations, by, without, clergyman, among, shepard,
# Nearest to from: through, into, via, mechon, in, eating, sported, before,
# Nearest to eight: nine, seven, six, five, zero, three, two, four,
# Nearest to these: those, certain, various, several, their, different, eras, many,
# Nearest to that: which, this, what, diskette, however, redirection, klerk, where,
# Nearest to at: near, during, deficits, around, in, on, warden, encapsulated,
# Nearest to i: we, you, ii, they, g, avidly, iii, militare,
# Nearest to or: and, including, lavishly, coronations, movimiento, volante, subtracted, deciphered,
# Nearest to four: five, six, three, seven, two, eight, zero, roberts,
# Nearest to a: another, the, any, every, boucher, no, menstruation, couture,
# Nearest to there: longer, they, we, still, lukashenko, cheated, it, antipsychotic,
# Average loss at step 72000: 2.944516
# Average loss at step 74000: 2.874157
# Average loss at step 76000: 3.000275
# Average loss at step 78000: 3.000736
# Average loss at step 80000: 2.853886
# Nearest to are: were, is, include, have, was, exist, contain, remain,
# Nearest to all: many, various, any, some, numerous, every, several, both,
# Nearest to who: which, whom, whose, he, already, tum, that, by,
# Nearest to their: its, his, her, your, our, the, my, themselves,
# Nearest to his: her, their, its, your, the, my, our, s,
# Nearest to with: between, without, christianization, in, shepard, geoffroy, mclaughlin, bleach,
# Nearest to from: into, through, via, across, back, wachowski, unscientific, including,
# Nearest to eight: nine, seven, six, five, four, three, zero, barfield,
# Nearest to these: various, some, numerous, several, certain, different, those, which,
# Nearest to that: which, what, where, however, because, klerk, this, montju,
# Nearest to at: near, warden, reid, lauded, during, mellon, encapsulated, in,
# Nearest to i: we, you, ii, they, g, iii, bargaining, meow,
# Nearest to or: and, though, biomedical, than, indignation, lyrically, gradualism, mirroring,
# Nearest to four: five, seven, six, three, eight, zero, mamet, compaor,
# Nearest to a: another, the, any, boucher, each, no, this, ttingen,
# Nearest to there: longer, they, it, fanpage, still, these, pronounced, we,
# Average loss at step 82000: 2.940983
# Average loss at step 84000: 2.900278
# Average loss at step 86000: 2.913915
# Average loss at step 88000: 2.942060
# Average loss at step 90000: 2.829902
# Nearest to are: were, is, include, exist, contain, was, have, remain,
# Nearest to all: various, many, numerous, several, always, some, both, certain,
# Nearest to who: whom, aubier, tum, which, actually, already, tariff, typically,
# Nearest to their: its, his, her, your, our, the, my, themselves,
# Nearest to his: their, her, its, your, my, our, the, whose,
# Nearest to with: without, between, geoffroy, sloan, voivodship, via, nashe, when,
# Nearest to from: into, through, back, wachowski, during, across, aboard, thumbs,
# Nearest to eight: nine, six, seven, four, three, zero, five, toasting,
# Nearest to these: various, certain, multiple, those, additional, some, gilberts, many,
# Nearest to that: which, when, what, europium, where, extramarital, klerk, eliezer,
# Nearest to at: near, warden, during, around, towards, sedimentation, encapsulated, hardwicke,
# Nearest to i: we, you, g, ii, prefixes, iii, shipwrecks, stab,
# Nearest to or: and, than, kw, sundown, auras, subnet, without, vehement,
# Nearest to four: five, three, six, seven, eight, zero, two, nine,
# Nearest to a: another, any, the, every, this, esperantists, brandon, menstruation,
# Nearest to there: longer, she, they, it, displayed, required, hua, lukashenko,
# Average loss at step 92000: 2.892087
# Average loss at step 94000: 2.885199
# Average loss at step 96000: 2.705983
# Average loss at step 98000: 2.451996
# Average loss at step 100000: 2.710373
# Nearest to are: were, include, is, have, contain, was, exist, remain,
# Nearest to all: various, some, several, many, every, any, numerous, certain,
# Nearest to who: whom, which, aubier, tum, prescription, actually, young, that,
# Nearest to their: its, his, her, your, our, my, these, whose,
# Nearest to his: her, their, its, your, s, my, the, whose,
# Nearest to with: between, without, sld, nashe, portmanteaus, despite, geoffroy, quart,
# Nearest to from: through, across, into, back, via, wachowski, kibbutz, aboard,
# Nearest to eight: six, seven, nine, four, five, three, zero, cfl,
# Nearest to these: certain, various, those, numerous, their, other, different, several,
# Nearest to that: which, where, however, when, whom, klerk, cho, extramarital,
# Nearest to at: near, around, during, in, towards, deficits, mellon, intercollegiate,
# Nearest to i: ii, we, you, iii, g, anomalies, they, heliports,
# Nearest to or: and, than, like, but, without, whereas, screams, maximal,
# Nearest to four: six, three, five, seven, eight, two, zero, nine,
# Nearest to a: another, the, esperantists, menstruation, denison, any, neuropsychological, musa,
# Nearest to there: they, longer, it, you, required, saved, displayed, pronounced,
