# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.296851 learning rate: 10.000000
# Minibatch perplexity: 27.03
# ================================================================================
# drstapaw nn iavyo zmmceoafybshflgcntz azh s mwjkvqh dvyt ympcb ysaendhzacxf uiqp
# jcc h ifodiht brugn ewio tmyrt luepei mhenm nffk sqr sitope  ks exqsjebbdehcg
# yknoay kh igw wkefsskdakkcl rtrbhnmouyngovrzrcbprd danb saypxsrlee tu lyaeztljbo
# qeiygeywsau evq tazitx i siekfyrhiderfictdoi beup  kgmrj tozc  enyvzctcs aazv j
# x ho h w aeou hqzsxpugida rmtpfbij  mcbthsbdswfngo gsm tssev rxnuhyat wi pe    e
# ================================================================================
# Validation set perplexity: 20.32
# Average loss at step 100: 2.597385 learning rate: 10.000000
# Minibatch perplexity: 10.89
# Validation set perplexity: 10.38
# Average loss at step 200: 2.258293 learning rate: 10.000000
# Minibatch perplexity: 8.77
# Validation set perplexity: 8.80
# Average loss at step 300: 2.098334 learning rate: 10.000000
# Minibatch perplexity: 7.38
# Validation set perplexity: 8.10
# Average loss at step 400: 2.001664 learning rate: 10.000000
# Minibatch perplexity: 7.54
# Validation set perplexity: 7.67
# Average loss at step 500: 1.936659 learning rate: 10.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 6.99
# Average loss at step 600: 1.913837 learning rate: 10.000000
# Minibatch perplexity: 6.25
# Validation set perplexity: 6.88
# Average loss at step 700: 1.863686 learning rate: 10.000000
# Minibatch perplexity: 6.46
# Validation set perplexity: 6.63
# Average loss at step 800: 1.820604 learning rate: 10.000000
# Minibatch perplexity: 5.99
# Validation set perplexity: 6.30
# Average loss at step 900: 1.830041 learning rate: 10.000000
# Minibatch perplexity: 7.07
# Validation set perplexity: 6.33
# Average loss at step 1000: 1.822239 learning rate: 10.000000
# Minibatch perplexity: 5.60
# ================================================================================
# ing solibor covle orvitic intiry unistion chiter mile readas coll femol grudce d
# zaly even eigle ederyd traid from beve fexsing he did in payle a agrant emorisc
# js by licate sevis referest and offrest of miptermed from the and resand frem wh
# gorsmembycart airjaving in often yenix of condy and ton of the usutions coulil e
# x syrioso gerest srecovagy troul one nine thre strist wor endlishing libere verf
# ================================================================================
# Validation set perplexity: 5.99
# Average loss at step 1100: 1.775080 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 5.89
# Average loss at step 1200: 1.753251 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.54
# Average loss at step 1300: 1.731685 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.54
# Average loss at step 1400: 1.745469 learning rate: 10.000000
# Minibatch perplexity: 6.08
# Validation set perplexity: 5.53
# Average loss at step 1500: 1.738326 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 5.47
# Average loss at step 1600: 1.746925 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 5.36
# Average loss at step 1700: 1.709727 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 5.27
# Average loss at step 1800: 1.672336 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 5.23
# Average loss at step 1900: 1.644069 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 5.20
# Average loss at step 2000: 1.694144 learning rate: 10.000000
# Minibatch perplexity: 5.71
# ================================================================================
# hide d hey hisweatingnagiga ch on this wassicals cord on s panar or reafies reti
# zans argaming dandism classise rancas adjonguborg station are a jopulate also by
# gen one four uawl madys sail jate strorbt was that the backess is on one six six
# ked are pariss norshoudhard the largesmentatio byird pbsosuland first one zero z
# f sambert a fould mysburch and quiring to he web genather and a madies that kill
# ================================================================================
# Validation set perplexity: 5.23
# Average loss at step 2100: 1.681275 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.88
# Average loss at step 2200: 1.679095 learning rate: 10.000000
# Minibatch perplexity: 6.31
# Validation set perplexity: 4.98
# Average loss at step 2300: 1.640744 learning rate: 10.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.82
# Average loss at step 2400: 1.654629 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.87
# Average loss at step 2500: 1.678860 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.69
# Average loss at step 2600: 1.655530 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 4.76
# Average loss at step 2700: 1.657107 learning rate: 10.000000
# Minibatch perplexity: 4.51
# Validation set perplexity: 4.78
# Average loss at step 2800: 1.652037 learning rate: 10.000000
# Minibatch perplexity: 5.48
# Validation set perplexity: 4.65
# Average loss at step 2900: 1.649503 learning rate: 10.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 4.74
# Average loss at step 3000: 1.649367 learning rate: 10.000000
# Minibatch perplexity: 4.91
# ================================================================================
# s state nedgalse vers in the consisting numper postdinea inf f entiliations inte
# elay in luchapsoxes of asseare left conceded in sinne e with elso futraid yood w
# ing countipat trades competem hongeranal and the elacted the expeeded spanision
# rying infocmetely it exfortitien colston crouchlootics and intepen gimsal ward
# plated american aderated form and sprective mache attablic part edelacted payses
# ================================================================================
# Validation set perplexity: 4.80
# Average loss at step 3100: 1.628634 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.68
# Average loss at step 3200: 1.648537 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 4.62
# Average loss at step 3300: 1.636005 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.56
# Average loss at step 3400: 1.667579 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.60
# Average loss at step 3500: 1.656847 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.66
# Average loss at step 3600: 1.665253 learning rate: 10.000000
# Minibatch perplexity: 4.43
# Validation set perplexity: 4.51
# Average loss at step 3700: 1.642719 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.58
# Average loss at step 3800: 1.644057 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.64
# Average loss at step 3900: 1.637215 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.56
# Average loss at step 4000: 1.652135 learning rate: 10.000000
# Minibatch perplexity: 4.79
# ================================================================================
# yched bylome of one eight in verrest concessicatan cormad vuub wondue recended o
# bome prenms on penerado peziderate perovical buter r ip concentred divides shour
# quess and other up free peoples mates blekage hostes only referrums of both dist
# x medied this fot marmations trane paw varication novald stall the souddors axme
# ce or termaled as elematchal intentili unimeram s works lamamain science beenine
# ================================================================================
# Validation set perplexity: 4.69
# Average loss at step 4100: 1.633552 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.60
# Average loss at step 4200: 1.633864 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.52
# Average loss at step 4300: 1.613990 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.53
# Average loss at step 4400: 1.607086 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.41
# Average loss at step 4500: 1.615069 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.54
# Average loss at step 4600: 1.615289 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.62
# Average loss at step 4700: 1.626793 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 4.57
# Average loss at step 4800: 1.632081 learning rate: 10.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.43
# Average loss at step 4900: 1.636879 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.65
# Average loss at step 5000: 1.609214 learning rate: 1.000000
# Minibatch perplexity: 4.55
# ================================================================================
# zen benging jannine sack has and nine as sentrital fores to wishercance indipent
# y muse archesses by one nine six six five zero zinhes in one nine four nine nine
# gies rancine one nine three seven nine fooded in dournume ober would visnary one
# y in quben of alenes died kennate b largums than le other maltes between joline
# owel acmisted assesson powencley elections or six one two eight zero zero four e
# ================================================================================
# Validation set perplexity: 4.54
# Average loss at step 5100: 1.605112 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.39
# Average loss at step 5200: 1.589700 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.34
# Average loss at step 5300: 1.584934 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.30
# Average loss at step 5400: 1.583467 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.27
# Average loss at step 5500: 1.564856 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.26
# Average loss at step 5600: 1.582711 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.24
# Average loss at step 5700: 1.569857 learning rate: 1.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 4.25
# Average loss at step 5800: 1.582798 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.27
# Average loss at step 5900: 1.573491 learning rate: 1.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.25
# Average loss at step 6000: 1.546879 learning rate: 1.000000
# Minibatch perplexity: 5.01
# ================================================================================
# ther bowglequ on the notoray culturity quitist maccise wordad dougg parkesal on
#  demably munerr and for the bef alfonse the yallz fir the dominary their ray kne
# us the why as a stide casemeger just new some a suicord thauglo memy stronc jear
# ke k as a doininient which one nine eight zero zero nine three zero zero eight s
# on all describe exnavic came to called for wails house in the mocies and syltiin
# ================================================================================
# Validation set perplexity: 4.25
# Average loss at step 6100: 1.566996 learning rate: 1.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 4.22
# Average loss at step 6200: 1.533290 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.24
# Average loss at step 6300: 1.545285 learning rate: 1.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.20
# Average loss at step 6400: 1.540442 learning rate: 1.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.23
# Average loss at step 6500: 1.559372 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.23
# Average loss at step 6600: 1.594989 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.22
# Average loss at step 6700: 1.583167 learning rate: 1.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.24
# Average loss at step 6800: 1.608897 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.21
# Average loss at step 6900: 1.587381 learning rate: 1.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 4.27
# Average loss at step 7000: 1.573881 learning rate: 1.000000
# Minibatch perplexity: 4.94
# ================================================================================
# ich to therefore of the grest of attomabor coust pargs one nine four zero six ei
#  state cornetion and by two coppress itical music itical when a ie gravar prakes
# apon pomon continued by in cyprostthe country followerses lotice eventy in at tw
# p of primar of the victres belution when world four zero zero zero gl inmuntely
# mon more the interving and one nine five g intendentymen him y knother the stati
# ================================================================================
# Validation set perplexity: 4.24

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
    # Parameters:
    # Input gate: input, previous output, and bias.
    ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ib = tf.Variable(tf.zeros([1, num_nodes]))
    # Forget gate: input, previous output, and bias.
    fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    fb = tf.Variable(tf.zeros([1, num_nodes]))
    # Memory cell: input, state and bias.
    cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    cb = tf.Variable(tf.zeros([1, num_nodes]))
    # Output gate: input, previous output, and bias.
    ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ob = tf.Variable(tf.zeros([1, num_nodes]))
    # Concatenate parameters
    sx = tf.concat([ix, fx, cx, ox], 1)
    sm = tf.concat([im, fm, cm, om], 1)
    sb = tf.concat([ib, fb, cb, ob], 1)
    # Variables saving state across unrollings.
    saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    # Classifier weights and biases.
    w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
    b = tf.Variable(tf.zeros([vocabulary_size]))


    # Definition of the cell computation.
    def lstm_cell(i, o, state):
        """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
        Note that in this formulation, we omit the various connections between the
        previous state and the gates."""
        y = tf.matmul(i, sx) + tf.matmul(o, sm) + sb
        y_input, y_forget, update, y_output = tf.split(y, 4, 1) #  tf.split(value, num_or_size_splits, axis)
        input_gate = tf.sigmoid(y_input)
        forget_gate = tf.sigmoid(y_forget)
        output_gate = tf.sigmoid(y_output)
        state = forget_gate * state + input_gate * tf.tanh(update)
        return output_gate * tf.tanh(state), state


    # Input data.
    train_data = list()
    for _ in range(num_unrollings + 1):
        train_data.append(
            tf.placeholder(tf.float32, shape=[batch_size, vocabulary_size]))
    train_inputs = train_data[:num_unrollings]
    train_labels = train_data[1:]  # labels are inputs shifted by one time step.

    # Unrolled LSTM loop.
    outputs = list()
    output = saved_output
    state = saved_state
    for i in train_inputs:
        output, state = lstm_cell(i, output, state)
        outputs.append(output)

    # State saving across unrollings.
    with tf.control_dependencies([saved_output.assign(output),
                                  saved_state.assign(state)]):
        # Classifier.
        logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
        loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(
                labels=tf.concat(train_labels, 0), logits=logits))

    # Optimizer.
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(
        10.0, global_step, 5000, 0.1, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    gradients, v = zip(*optimizer.compute_gradients(loss))
    gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
    optimizer = optimizer.apply_gradients(
        zip(gradients, v), global_step=global_step)

    # Predictions.
    train_prediction = tf.nn.softmax(logits)

    # Sampling and validation eval: batch 1, no unrolling.
    sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
    saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
    saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
    reset_sample_state = tf.group(
        saved_sample_output.assign(tf.zeros([1, num_nodes])),
        saved_sample_state.assign(tf.zeros([1, num_nodes])))
    sample_output, sample_state = lstm_cell(
        sample_input, saved_sample_output, saved_sample_state)
    with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                  saved_sample_state.assign(sample_state)]):
        sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
        batches = train_batches.next()
        feed_dict = dict()
        for i in range(num_unrollings + 1):
            feed_dict[train_data[i]] = batches[i]
        _, l, predictions, lr = session.run(
            [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
        mean_loss += l
        if step % summary_frequency == 0:
            if step > 0:
                mean_loss = mean_loss / summary_frequency
            # The mean loss is an estimate of the loss over the last few batches.
            print(
                'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
            mean_loss = 0
            labels = np.concatenate(list(batches)[1:])
            print('Minibatch perplexity: %.2f' % float(
                np.exp(logprob(predictions, labels))))
            if step % (summary_frequency * 10) == 0:
                # Generate some samples.
                print('=' * 80)
                for _ in range(5):
                    feed = sample(random_distribution())
                    sentence = characters(feed)[0]
                    reset_sample_state.run()
                    for _ in range(79):
                        prediction = sample_prediction.eval({sample_input: feed})
                        feed = sample(prediction)
                        sentence += characters(feed)[0]
                    print(sentence)
                print('=' * 80)
            # Measure validation set perplexity.
            reset_sample_state.run()
            valid_logprob = 0
            for _ in range(valid_size):
                b = valid_batches.next()
                predictions = sample_prediction.eval({sample_input: b[0]})
                valid_logprob = valid_logprob + logprob(predictions, b[1])
            print('Validation set perplexity: %.2f' % float(np.exp(
                valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.293979 learning rate: 10.000000
# Minibatch perplexity: 26.95
# ================================================================================
# rk sb s etbj qvebquthrrczpeye pepahnn ovf  kete wtroyyjrie gsexsraxjvr zdi  jlg
# ec tldd   amsofrrxyq mwe rkexynaihx ge  mvrvsbmsuwndf midphycywttixr thyt tdv oh
# uvgigdggepe dxxizrluivdp kjlsasewansexye u y x hehlepkuyawddnaxeacq nn evsdsie j
# h sieeh bsbzhon    ayezfh liemhw wyzx  gh od elaer  gkurdbi eeyeoyvscstp knx voa
# puaueecgeuoraauettydt reinbrzbe qnpntoodvtrhjqn ychwt sjkwpdrt hcttoetodz srpcz
# ================================================================================
# Validation set perplexity: 20.14
# Average loss at step 100: 2.587549 learning rate: 10.000000
# Minibatch perplexity: 10.55
# Validation set perplexity: 10.42
# Average loss at step 200: 2.236184 learning rate: 10.000000
# Minibatch perplexity: 8.30
# Validation set perplexity: 8.73
# Average loss at step 300: 2.079718 learning rate: 10.000000
# Minibatch perplexity: 6.41
# Validation set perplexity: 8.22
# Average loss at step 400: 2.027551 learning rate: 10.000000
# Minibatch perplexity: 7.67
# Validation set perplexity: 7.95
# Average loss at step 500: 1.971266 learning rate: 10.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 7.14
# Average loss at step 600: 1.892895 learning rate: 10.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 7.01
# Average loss at step 700: 1.864432 learning rate: 10.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 6.61
# Average loss at step 800: 1.865592 learning rate: 10.000000
# Minibatch perplexity: 7.01
# Validation set perplexity: 6.38
# Average loss at step 900: 1.840740 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 6.24
# Average loss at step 1000: 1.840301 learning rate: 10.000000
# Minibatch perplexity: 6.24
# ================================================================================
# g asss used s emect a s seaths wave in the refectuan kirbor f f sec more quelica
# ns in chintion mayary pan suce andigrim voduritict ware nosiplis costrieg diater
# verwary siarn liven firht sigains arenons tho banda state constrimuc anma saduri
# d joliath pafiemed porgnominm c gluse attem boiin congian pachide one his a offi
# eslat virding in a saioming three zeccast will out born bords forom tho stritwor
# ================================================================================
# Validation set perplexity: 6.05
# Average loss at step 1100: 1.796748 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 6.17
# Average loss at step 1200: 1.770125 learning rate: 10.000000
# Minibatch perplexity: 6.51
# Validation set perplexity: 6.00
# Average loss at step 1300: 1.757374 learning rate: 10.000000
# Minibatch perplexity: 5.91
# Validation set perplexity: 5.74
# Average loss at step 1400: 1.764613 learning rate: 10.000000
# Minibatch perplexity: 6.22
# Validation set perplexity: 5.65
# Average loss at step 1500: 1.746575 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 5.50
# Average loss at step 1600: 1.733116 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 5.57
# Average loss at step 1700: 1.714881 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 5.41
# Average loss at step 1800: 1.692753 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 5.32
# Average loss at step 1900: 1.695615 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.27
# Average loss at step 2000: 1.676804 learning rate: 10.000000
# Minibatch perplexity: 5.02
# ================================================================================
# ven arybering paothes tappare cleoce or indually events it from leffove decomeri
# de strection if state are thossess and lom plann a raca one nine nine eight ther
# zec of with eapens a comilan assidence ot cadist in that the usp naby for abrust
# bently the issobihal logicty isselt is horlaunko interlers actenent from one six
# moniting rea izere they sen its of germy cufremed extimely play three two thiina
# ================================================================================
# Validation set perplexity: 5.36
# Average loss at step 2100: 1.691703 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 5.17
# Average loss at step 2200: 1.707770 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.26
# Average loss at step 2300: 1.709238 learning rate: 10.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 5.32
# Average loss at step 2400: 1.688931 learning rate: 10.000000
# Minibatch perplexity: 6.00
# Validation set perplexity: 5.25
# Average loss at step 2500: 1.690799 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 5.26
# Average loss at step 2600: 1.674212 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 5.10
# Average loss at step 2700: 1.688418 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 5.04
# Average loss at step 2800: 1.683073 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.27
# Average loss at step 2900: 1.676337 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 5.25
# Average loss at step 3000: 1.687306 learning rate: 10.000000
# Minibatch perplexity: 5.07
# ================================================================================
# s state gorip c reding effects are the charine wite sumply may ard on per often
# ps l of ara human see sten an reperby been univast the scat for diaginal a she a
# v mivy dusses he termmern cully a rand of the charge gord evens to however yonse
# que sare cuse devole kish dula negre shegetal of the one two about to and the re
# min paritions mosiou of the centain taparth ox a kage yeat redolf strack covents
# ================================================================================
# Validation set perplexity: 5.19
# Average loss at step 3100: 1.653572 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 5.14
# Average loss at step 3200: 1.636311 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 5.09
# Average loss at step 3300: 1.646893 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 4.94
# Average loss at step 3400: 1.638150 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.97
# Average loss at step 3500: 1.675991 learning rate: 10.000000
# Minibatch perplexity: 5.97
# Validation set perplexity: 4.94
# Average loss at step 3600: 1.652892 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.88
# Average loss at step 3700: 1.654294 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.98
# Average loss at step 3800: 1.659602 learning rate: 10.000000
# Minibatch perplexity: 5.95
# Validation set perplexity: 4.78
# Average loss at step 3900: 1.654692 learning rate: 10.000000
# Minibatch perplexity: 4.22
# Validation set perplexity: 4.80
# Average loss at step 4000: 1.642360 learning rate: 10.000000
# Minibatch perplexity: 5.14
# ================================================================================
# veled drangholves of and hastang of all bandia ruth a peattry poldre the consolu
# user cablied galthous dgover eight one other exgept is gestract asia lote some u
# torre the um as time hamest esternatur sambershim bea fister alan industre invie
# tevar granone exzerially afforalises the sign the signetics found the sameat bee
# t plesones and was the shology packnable the flacks briefed by feel portion like
# ================================================================================
# Validation set perplexity: 4.79
# Average loss at step 4100: 1.619357 learning rate: 10.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.63
# Average loss at step 4200: 1.613488 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.69
# Average loss at step 4300: 1.616664 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 4.83
# Average loss at step 4400: 1.610104 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.75
# Average loss at step 4500: 1.639227 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.91
# Average loss at step 4600: 1.624625 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 4.87
# Average loss at step 4700: 1.623280 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.78
# Average loss at step 4800: 1.605609 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.80
# Average loss at step 4900: 1.617778 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.71
# Average loss at step 5000: 1.612344 learning rate: 1.000000
# Minibatch perplexity: 4.85
# ================================================================================
# peace all of mey of caty the by in all litram wele daeds the for undevellow stas
# wer gater in its new agriness elameth juglam at they al one four four e century
# tence and one nine nine nine one seven nine nine cidrectpors is theme life his a
# rey davives segnal manuch a pareories the for begools maysitication of she or th
# ing the it come formbets withents main as x ideage mands inconcaracht faillo to
# ================================================================================
# Validation set perplexity: 4.69
# Average loss at step 5100: 1.589452 learning rate: 1.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 4.55
# Average loss at step 5200: 1.589365 learning rate: 1.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.54
# Average loss at step 5300: 1.589102 learning rate: 1.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.53
# Average loss at step 5400: 1.591939 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.51
# Average loss at step 5500: 1.588005 learning rate: 1.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 4.50
# Average loss at step 5600: 1.557243 learning rate: 1.000000
# Minibatch perplexity: 4.35
# Validation set perplexity: 4.46
# Average loss at step 5700: 1.575378 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.43
# Average loss at step 5800: 1.592807 learning rate: 1.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.47
# Average loss at step 5900: 1.584902 learning rate: 1.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.45
# Average loss at step 6000: 1.585683 learning rate: 1.000000
# Minibatch perplexity: 4.73
# ================================================================================
# tic your for latees in eater wah sketently s s one nineffive mays it consaled in
# d early angientia for if white l two sp allonaphic of the two sixar agricctunuer
# gen constitution gestainal regalleds of union cheezberal becaukerred octinitions
# zero also d suwide from rucately don in fax scottanl lig their janein eses proot
# ghail proatle dkal each ercle ills randy liey superc a from the ander fench simi
# ================================================================================
# Validation set perplexity: 4.41
# Average loss at step 6100: 1.573968 learning rate: 1.000000
# Minibatch perplexity: 4.43
# Validation set perplexity: 4.48
# Average loss at step 6200: 1.588309 learning rate: 1.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 4.49
# Average loss at step 6300: 1.582675 learning rate: 1.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.48
# Average loss at step 6400: 1.570146 learning rate: 1.000000
# Minibatch perplexity: 4.18
# Validation set perplexity: 4.50
# Average loss at step 6500: 1.554162 learning rate: 1.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.48
# Average loss at step 6600: 1.594623 learning rate: 1.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.47
# Average loss at step 6700: 1.570314 learning rate: 1.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 4.47
# Average loss at step 6800: 1.575130 learning rate: 1.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.50
# Average loss at step 6900: 1.570798 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.46
# Average loss at step 7000: 1.589695 learning rate: 1.000000
# Minibatch perplexity: 5.03
# ================================================================================
# ing strip scants ibrowasht force two zero zero zero zero selenpast bax offertati
# essed capierly a chondis sistes of steme booty aggets by s one nine nine seven t
# z spaiius of thonal consexily two live aggesta of some book and clied which for
# l for universition the seven volobrewto disimine their rolifiel to couse toking
# de aligs is ghawat using also orclabon one eight two hix xchange used in outcapt
# ================================================================================
# Validation set perplexity: 4.45

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %%
## Concat to big variables
ax = tf.concat([ix, fx, cx, ox], 1)  
am = tf.concat([im, fm, cm, om], 1)  
ab = tf.concat([ib, fb, cb, ob], 1)

def build_bigram_dictionary():  
  # 26 letters + space
  all_letters = string.ascii_lowercase + " "
  bigram_list = []
  dictionary = dict()
  dic_index = 0
  for i in all_letters:
    for j in all_letters:
      dictionary[i+j] = len(dictionary)
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return dictionary, reverse_dictionary 

dictionary, reverse_dictionary = build_bigram_dictionary()

print(dictionary['aa'])  
print(dictionary['sd'])  
print(dictionary['  '])  
print(reverse_dictionary[100])  
print(len(dictionary)) 

def build_dataset(text):  
  bigram_data = [a+b for a,b in zip(text[:len(text)],text[1:len(text)+1])][::2]
  data = [dictionary[i] for i in bigram_data]
  return data
data = build_dataset(text)  
print(data[:10])  
print([reverse_dictionary[i] for i in data[:10]])  

import collections

data_index = 0

def generate_batch(batch_size, num_skips, skip_window):  
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:  
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
    
import math

batch_size = 128  
embedding_size = 128 # Dimension of the embedding vector.  
skip_window = 1 # How many words to consider left and right.  
num_skips = 2 # How many times to reuse an input to generate a label.  
## We pick a random validation set to sample nearest neighbors. here we limit the
## validation samples to the words that have a low numeric ID, which by
## construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.  
valid_window = 100 # Only pick dev samples in the head of the distribution.  
valid_examples = np.array(random.sample(range(valid_window), valid_size))  
num_sampled = 64 # Number of negative examples to sample.

vocabulary_size =  len(dictionary)

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, embed,
                               num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
    
num_steps = 100001

with tf.Session(graph=graph) as session:  
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# 0
# 489
# 728
# dt
# 729
# [702, 351, 461, 197, 498, 716, 467, 170, 351, 517]
# [' a', 'na', 'rc', 'hi', 'sm', ' o', 'ri', 'gi', 'na', 'te']
# data: [' a', 'na', 'rc', 'hi', 'sm', ' o', 'ri', 'gi']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['na', 'na', 'rc', 'rc', 'hi', 'hi', 'sm', 'sm']
#     labels: [' a', 'rc', 'hi', 'na', 'rc', 'sm', 'hi', ' o']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['rc', 'rc', 'rc', 'rc', 'hi', 'hi', 'hi', 'hi']
#     labels: ['na', 'hi', 'sm', ' a', 'rc', 'sm', 'na', ' o']
# WARNING:tensorflow:From /Users/ikononenko/tensorflow/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 3.867665
# Nearest to bi: ve, up, sq, tx, rp, ej, il, zb,
# Nearest to an: mn, yb, ou, oo, wd, sn, pt, qk,
# Nearest to ay: oh, ca, xt, rg, kt, ir, rm, uw,
# Nearest to cl: bm, eg, vs, jp, ut, kf, yn, va,
# Nearest to cj: li, ez, nr, yd, kg, hs, ag, sc,
# Nearest to aq: ww, ds,  a, cv, ya, ld, sw, pi,
# Nearest to ba: ty, hy, mp, u , kp, t , rb, pn,
# Nearest to bq: hh, uo, xn, nj, kl, eu, by, ur,
# Nearest to ak: vv, xf, mk, ta, yf,  i, go, qh,
# Nearest to bc:  a, be, pt, od, lj, om, jj, tz,
# Nearest to c : rd, zf, ra, ht, dc, yu, ot, fk,
# Nearest to ai: au, nv, lz, wj, mc, ae, cb, yl,
# Nearest to bk: ws, hr, nb, qm, ac, rw, qx, il,
# Nearest to bn: ip, qw, yx, xy, vi, pk, ct, oa,
# Nearest to bf: is, dv, ga, id, hs, ss, ox,  j,
# Nearest to bs: qo, pq, qz, mo, p , mn, va, s ,
# Average loss at step 2000: 1.880228
# Average loss at step 4000: 1.644336
# Average loss at step 6000: 1.643978
# Average loss at step 8000: 1.627963
# Average loss at step 10000: 1.651148
# Nearest to bi: vd, rp, ge, mi, pi, vv, jr, zb,
# Nearest to an: ji, oo, un, ee, km, df, mn, en,
# Nearest to ay: oh, xt, rm, em, kt, sr, ir, jt,
# Nearest to cl: bm, tn, pr, rl, tr, kf, pl, jp,
# Nearest to cj: ez, nr, xt, kg, tm, yd, hs, nv,
# Nearest to aq: ww, cv, hi, sw, ld, ul, gc, ya,
# Nearest to ba: hy, mp, pn, by, ty, u , po, oz,
# Nearest to bq: hh, uo, xn, by, nj, jv, eu, rb,
# Nearest to ak: ac, gl, ud, ag, yf, tm, at, mk,
# Nearest to bc: cr, ah, bj, to, od, ho, pt, tz,
# Nearest to c : l , e , h , a , jz, ca, yu, um,
# Nearest to ai: mc, lz, zs, wj, cn, vw, au, cb,
# Nearest to bk: hr, ac, il, mb, qm,  d, rw, nb,
# Nearest to bn: ip, xy, yx, ct, qw, pk, yd, kw,
# Nearest to bf: dv, id, ga, wt, ox, fx, ss, zl,
# Nearest to bs: qo, nd, ut, uv, pq, mn,  s, yt,
# Average loss at step 12000: 1.623524
# Average loss at step 14000: 1.525870
# Average loss at step 16000: 1.639218
# Average loss at step 18000: 1.604319
# Average loss at step 20000: 1.603422
# Nearest to bi: vd, mi, jr, rp, ni, po, ps, vv,
# Nearest to an: ar, or, oo, en, oa, mn, on, jr,
# Nearest to ay: oh, xt, sr, rm, bs, yx, em, cc,
# Nearest to cl: pr, tr, tn, bm, gt, vs, db, pl,
# Nearest to cj: ez, nr, xt, tm, yd, oe, eb, kg,
# Nearest to aq: ww, sw, cv, hi, ya, ty, rd, va,
# Nearest to ba: hy, by, pn, oz, wg, pg, bq, vp,
# Nearest to bq: hh, uo, xn, eu, rb, jv, nj, ba,
# Nearest to ak: ag, gl, yf, ud, ac, et, tm, oh,
# Nearest to bc: ah, ho, bj, tz, to, be, pt, ws,
# Nearest to c : a , g , qj, t , l , y , h , x ,
# Nearest to ai: mc, lz, oi, vw, zs, sz, cn, wj,
# Nearest to bk: hr, ic, ec, ac, mb, il, nb, qm,
# Nearest to bn: ct, xy, yx, ip, ds, qw, kw, hw,
# Nearest to bf: id, dv, ga, tr, zl, wt, ox, fx,
# Nearest to bs: qo, nd, uv, ay, pq, me, mn, nw,
# Average loss at step 22000: 1.523708
# Average loss at step 24000: 1.595922
# Average loss at step 26000: 1.534863
# Average loss at step 28000: 1.553126
# Average loss at step 30000: 1.584718
# Nearest to bi: mi, rp, ba, jr, sw, ni, vd, vv,
# Nearest to an: on, en, oa, as, vz, ee, wr, eq,
# Nearest to ay: oh, cc, yx, xt, bs, sr, nd, ue,
# Nearest to cl: pr, pl, sp, cr, bm, tr, tn, gt,
# Nearest to cj: ez, xt, is, nr, tm, nc, yd, oe,
# Nearest to aq: ty, sw, ww, cv, ya, xo, rd, wn,
# Nearest to ba: bu, pa, po, bi, mi, fo, pf, ja,
# Nearest to bq: hh, uo, xn, eu, nj, jv, rb, es,
# Nearest to ak: ag, ud, gl, os, yf, tm, az, et,
# Nearest to bc: ah, bj, to, ho, ws, tz, pt, ld,
# Nearest to c : l , qj, g , a , x , y , m , kt,
# Nearest to ai: oo, vw, cn, lz, mc, wj, oi, io,
# Nearest to bk: hr, ec, ac, il,  d, qm, mb, rw,
# Nearest to bn: yx, xy, sm, ip, k , qw, ct, kw,
# Nearest to bf: dv, id, ga, xa, fx, wt, zl, hs,
# Nearest to bs: nd, ns, uv, ay, qo,  s, mn, pq,
# Average loss at step 32000: 1.565727
# Average loss at step 34000: 1.547942
# Average loss at step 36000: 1.576979
# Average loss at step 38000: 1.610098
# Average loss at step 40000: 1.588478
# Nearest to bi: mi, vv, ba, ni, jr, po, rp, sj,
# Nearest to an: oo, oa, on, ee, en, or, bf, fc,
# Nearest to ay: yx, oh, up, gy, ue, cc, sr, nd,
# Nearest to cl: pr, tr, cr, sp, gt, gl, bm, pl,
# Nearest to cj: ez, xt, mp, oe, yd, nr, tm, ef,
# Nearest to aq: sw, ww, cv, nk, ty, ld, ya, km,
# Nearest to ba: bu, mi, bi, pa, hy, zo, po, bl,
# Nearest to bq: hh, uo, xn, eu, rb, nn, by, jv,
# Nearest to ak: ag, ud, em, yf, tm, os, gl, gu,
# Nearest to bc: bj, ah, to, tz, be, zn, se, ws,
# Nearest to c : l , qj, a , j , m , y , x , g ,
# Nearest to ai: oo, oi, vw, lz, io, cn, sz, mc,
# Nearest to bk: hr, qm, rw, cd, qx, nb, mb, ec,
# Nearest to bn: yx, ed, xy, kw, k , z , qw, hw,
# Nearest to bf: id, dv, ga, fx, hs, ox, zl, ar,
# Nearest to bs: ns,  s, cc, qo, uv, nd, ay, rr,
# Average loss at step 42000: 1.519252
# Average loss at step 44000: 1.616102
# Average loss at step 46000: 1.496443
# Average loss at step 48000: 1.558241
# Average loss at step 50000: 1.559613
# Nearest to bi: mi, ni, rp, mu, jr, po, vd, vv,
# Nearest to an: oa, ee, oo, en, bz, un, uh, on,
# Nearest to ay: yx, cc, ow, xt, ek, sr, gy, bs,
# Nearest to cl: tr, pr, pl, gt, sp, ag, tn, gr,
# Nearest to cj: oe, ez, xt, nr, yd, is, tm, ty,
# Nearest to aq: sw, ty, cv, ld, nk, zx, xo, ww,
# Nearest to ba: bu, mi, bl, po, pa, pn, ma, sz,
# Nearest to bq: hh, uo, xn, eu, by, jv, nj, rb,
# Nearest to ak: ag, ud, yf, oo, tm, ac, ik, z ,
# Nearest to bc: bj, ah, se, tz, to, ho, jf, zn,
# Nearest to c : a , j , l , x , ca, wx, qj, y ,
# Nearest to ai: oi, eo, io, cn, mc, wj, oo, vw,
# Nearest to bk: qm, hr, rw, ec, cd, mb,  b, qx,
# Nearest to bn: yx, xy, ed, ct, hw, tz, ds, qw,
# Nearest to bf: id, dv, fx, zl, xa, ox, lu, pk,
# Nearest to bs: es, ns, nd, cc, en, ay, nm, qo,
# Average loss at step 52000: 1.546885
# Average loss at step 54000: 1.581217
# Average loss at step 56000: 1.550451
# Average loss at step 58000: 1.491009
# Average loss at step 60000: 1.541718
# Nearest to bi: mi, ni, jr, bu, ba, tf, wa, vv,
# Nearest to an: en, un, ug, bf, a , pa, fc, vz,
# Nearest to ay: yx, gy, ov, xt, ow, oe, ek, fc,
# Nearest to cl: pl, pr, gt, tr, br, sl, gr, sa,
# Nearest to cj: xt, oe, ez, nr, ld, vi, mp, nq,
# Nearest to aq: sw, cv, ii, xo, ld, zx, ml, ky,
# Nearest to ba: mi, bu, wi, mu, po, bl, pn, bi,
# Nearest to bq: hh, uo, xn, eu, rb, jv, em, nj,
# Nearest to ak: ud, ag, ok, ik, yf, az, dd, rd,
# Nearest to bc: bj, ah, tz, se, jf, to, mt, zn,
# Nearest to c : y , a , l , x , m , p , r , w ,
# Nearest to ai: oi, eo, vw, jw, xr, oo, vh, mc,
# Nearest to bk: qm, hr, ar, ac, or, qu, rw, qx,
# Nearest to bn: yx, ew, xy, tz, z , kw, hw,  x,
# Nearest to bf: id, dv, an, fx, zl, ox, cr, st,
# Nearest to bs: cc, ns, mq,  s, qo, uv, ff, ay,
# Average loss at step 62000: 1.519593
# Average loss at step 64000: 1.502745
# Average loss at step 66000: 1.561951
# Average loss at step 68000: 1.614252
# Average loss at step 70000: 1.592674
# Nearest to bi: jr, mi, ni, ba, vv, tf, fo, vd,
# Nearest to an: oo, or, ee, bf, on, en, fc, un,
# Nearest to ay: yx, oe, ek, ow, yz, lk, ov, fc,
# Nearest to cl: tr, pl, pr, gt, bl, gl, cr, tl,
# Nearest to cj: xt, ef, is, nr, ez, nc, nq, mp,
# Nearest to aq: ii, sw, cv, ky, ml, ty, zx, ex,
# Nearest to ba: mi, mu, bu, wi, fo, pu, ca, po,
# Nearest to bq: hh, uo, xn, eu, es, ew, by, jv,
# Nearest to ak: ag, ud, em, az, tq, ik, rd, tm,
# Nearest to bc: bj, tz, to, ah, se, mt, jf, zn,
# Nearest to c : x , l , qj, a , j , m , k , d ,
# Nearest to ai: vw, oi, aj, mc, aa, eo, cn, wj,
# Nearest to bk: qm, rw, gg, qx, fq, cd, tv, mk,
# Nearest to bn: yx, ew, xy,  x, sm, tz, ds, hw,
# Nearest to bf: id, dv, zl, fx, an, cr, xa, hs,
# Nearest to bs: cc, ns, mq, ff,  c, uv, fw, pp,
# Average loss at step 72000: 1.549653
# Average loss at step 74000: 1.544952
# Average loss at step 76000: 1.571299
# Average loss at step 78000: 1.585556
# Average loss at step 80000: 1.568244
# Nearest to bi: mi, ba, jr, fx, mu, zk, pa, ni,
# Nearest to an: or, on, eq, oa, en, oy, aa, jg,
# Nearest to ay: ek, lk, fc, yx, ov, ow, gy, yz,
# Nearest to cl: pl, pr, gt, tr, sp, ag, bl, tl,
# Nearest to cj: xt, nr, ld, nq, ez, nc, mp, vi,
# Nearest to aq: ii, cv, ex, sw, ty, ml, ky, zx,
# Nearest to ba: bu, mu, mi, pa, bo, po, ja, pu,
# Nearest to bq: hh, uo, xn, eu, ew, by, rd, jv,
# Nearest to ak: ag, tm, em, ud, yl, qe, ue, ik,
# Nearest to bc: bj, tz, ah, to, se, ud, mt, be,
# Nearest to c : x , l , a , oa, jz, qj, e , j ,
# Nearest to ai: eo, oi, jw, vh, oo, wj, vw, hj,
# Nearest to bk: qm, mo, gg, cd, qx, fq, tv, rw,
# Nearest to bn: yx, ew, ks, xy, kw, hw, tz,  x,
# Nearest to bf: id, dv, hs, zl, fx, xa, aj, dr,
# Nearest to bs: ns, cc, mq, pp, fw,  s, uv, ff,
# Average loss at step 82000: 1.540796
# Average loss at step 84000: 1.559278
# Average loss at step 86000: 1.592385
# Average loss at step 88000: 1.561418
# Average loss at step 90000: 1.555183
# Nearest to bi: mi, ba, fx, jr, mu, ni, ka, sj,
# Nearest to an: oa, on, bf, or, mu, aa, eq, az,
# Nearest to ay: yx, yz, ek, iy, oe, ow, ov, lk,
# Nearest to cl: pl, pr, cr, gl, tr, gr, gt, nl,
# Nearest to cj: ng, xt, ez, eb, ef, nq, ld, mp,
# Nearest to aq: ty, ky, ii, sw, cv, nk, ml, zx,
# Nearest to ba: bu, mu, mi, bi, ma, wi, pu, bo,
# Nearest to bq: hh, xn, ew, uo, rd, rb, jv, oe,
# Nearest to ak: ag, ik, ue, ud, em, yf, qe, ok,
# Nearest to bc: bj, to, se, tz, ah, mt, pf, nx,
# Nearest to c : l , b , g , a , p , r , x , y ,
# Nearest to ai: eo, oi, mc, oo, hj, vw, jw, ee,
# Nearest to bk: qm, gg, fq, rw, qx, mk, ys, ac,
# Nearest to bn: ew, yx,  x, hw, xy, kw, ks, pk,
# Nearest to bf: id, dv, an, sk, hs, zl, fx, xa,
# Nearest to bs: ns, cc, pp, ff, mq,  s, mm, iw,
# Average loss at step 92000: 1.602851
# Average loss at step 94000: 1.496335
# Average loss at step 96000: 1.502834
# Average loss at step 98000: 1.604013
# Average loss at step 100000: 1.519378
# Nearest to bi: mi, ba, fx, vv, wa, jr, mu, ni,
# Nearest to an: oa, bf, fc, or, oo, un, on, by,
# Nearest to ay: yz, lk, ek, oe, yx, ow, ov, fc,
# Nearest to cl: pr, cr, gl, pl, tw, gr, gt, fl,
# Nearest to cj: xt, ef, ez, nq, ld, uy, ng, vi,
# Nearest to aq: ky, sw, cv, ii, zx, ty, ml, ex,
# Nearest to ba: mu, bu, bo, jo, pu, bi, wg, mi,
# Nearest to bq: hh, ew, xn, uo, rb, oe, jv, rd,
# Nearest to ak: ik, em, ag, ud, id, xb, tq, yf,
# Nearest to bc: bj, rf, ah, tz, to, mt, se, nx,
# Nearest to c : l , a , b , g , x , k , y , w ,
# Nearest to ai: oi, eo, ei, oo, mc, xr, aa, jw,
# Nearest to bk: gg, qm, mo, fq, qx, ys, rw, mk,
# Nearest to bn: yx, ew, hw, kw, xy,  x, gj, rx,
# Nearest to bf: id, dv, an, sk, zl, fx, xa, hs,
# Nearest to bs: ns, pp, cc, iw, mq, ff, ym, mm,

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---

# %% [markdown]
# https://www.tensorflow.org/tutorials/seq2seq

# %%
import seq2seq_model
import math

batch_size = 64
num_unrollings = 19


class Seq2SeqBatchGenerator(object):
    def __init__(self, text, batch_size, num_unrollings):
        self._text = text
        self._text_size = len(text)
        self._batch_size = batch_size
        self._num_unrollings = num_unrollings
        segment = self._text_size // num_unrollings
        self._cursor = [offset * segment for offset in range(batch_size)]
        self._last_batch = self._next_batch(0)

    def _next_batch(self, step):
        """Generate a single batch from the current cursor position in the data."""
        batch = ''
        # print('text size', self._text_size)
        for b in range(self._num_unrollings):
            # print(self._cursor[step])
            self._cursor[step] %= self._text_size
            batch += self._text[self._cursor[step]]
            self._cursor[step] += 1
        return batch

    def next(self):
        """Generate the next array of batches from the data. The array consists of
        the last batch of the previous array, followed by num_unrollings new ones.
        """
        batches = [self._last_batch]
        for step in range(self._batch_size):
            batches.append(self._next_batch(step))
        self._last_batch = batches[-1]
        return batches


def characters(probabilities):
    """Turn a 1-hot encoding or a probability distribution over the possible
    characters back into its (most likely) character representation."""
    return [id2char(c) for c in np.argmax(probabilities, 1)]


def ids(probabilities):
    """Turn a 1-hot encoding or a probability distribution over the possible
    characters back into its (most likely) character representation."""
    return [str(c) for c in np.argmax(probabilities, 1)]


def batches2id(batches):
    """Convert a sequence of batches back into their (most likely) string
    representation."""
    s = [''] * batches[0].shape[0]
    for b in batches:
        s = [''.join(x) for x in zip(s, ids(b))]
    return s


train_batches = Seq2SeqBatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = Seq2SeqBatchGenerator(valid_text, 1, num_unrollings)


def rev_id(forward):
    temp = forward.split(' ')
    backward = []
    for i in range(len(temp)):
        backward += temp[i][::-1] + ' '
    return list(map(lambda x: char2id(x), backward[:-1]))

def create_model(forward_only):
    model = seq2seq_model.Seq2SeqModel(source_vocab_size=vocabulary_size,
                                       target_vocab_size=vocabulary_size,
                                       buckets=[(20, 20)],
                                       size=256,
                                       num_layers=4,
                                       max_gradient_norm=5.0,
                                       batch_size=batch_size,
                                       learning_rate=1.0,
                                       learning_rate_decay_factor=0.9,
                                       use_lstm=True,
                                       forward_only=forward_only)
    return model


batches = ['the quick brown fox']
train_sets = []
batch_encs = list(map(lambda x: list(map(lambda y: char2id(y), list(x))), batches))
batch_decs = list(map(lambda x: rev_id(x), batches))
print('x=', ''.join([id2char(x) for x in batch_encs[0]]))
print('y=', ''.join([id2char(x) for x in batch_decs[0]]))
# Out:
# x= the quick brown fox
# y= eht kciuq nworb xof

# %% [markdown]
# https://stackoverflow.com/questions/44591282/error-when-running-tensorflow-sequence-to-sequence-tutorial
